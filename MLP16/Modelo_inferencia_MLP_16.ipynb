# %% [markdown]
# # Primeiramente é preciso carregar os dados para inferência no formato .csv
#
# ### No arquivo example_mlp16.csv está um exemplo de como os dados devem estar ordenados
#
# #### O modelo utiliza para as inferências as variávies :
#
# Depth_113Ma_Base_Sal_Profundidade_Area_PUC_RJ', 'Depth_134Ma_Topo_Embasamento_Indistinto_Profundidade_Area_PUC_RJ',  'Depth_CT_Espessura_Crustal_Area_PUC_RJ', 'falha_dist   '1_M_falha_dist', '2_M_falha_dist', '3_M_falha_dist', '4_M_falha_dist    '5_M_falha_dist', '6_M_falha_dist', '7_M_falha_dist', '8_M_falha_di      '9_M_falha_dist', '10_M_falha_dist', 'Ignea', 'dist_Ig      'magnometria', 'gravitometria', 'fluxo_termico', 'gradiente_te2_poco'

# %%
import numpy as np
import joblib
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error,accuracy_score
from sklearn import preprocessing
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
import lime
import lime.lime_tabular
import pandas as pd

# %%
df=pd.read_csv(r'example_mlp16.csv')

# %% [markdown]
# ## É   preciso pre processar os dados para o formato de como foram treinados

# %%
#from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd
from sklearn import preprocessing

x = df.values  #returns a numpy array
std_scaller = preprocessing.StandardScaler()
x_scaled = std_scaller.fit_transform(x)
df = pd.DataFrame(x_scaled,columns=df.columns, index=df.index)

# %%
df.head()
# Out:
#    Depth_113Ma_Base_Sal_Profundidade_Area_PUC_RJ  \
# 0                                       3.501445
# 1                                       2.076126
# 2                                       0.233081
# 3                                      -0.329098
# 4                                      -0.067415
#
#    Depth_134Ma_Topo_Embasamento_Indistinto_Profundidade_Area_PUC_RJ  \
# 0                                           3.703396
# 1                                           1.561897
# 2                                           0.399997
# 3                                          -0.696245
# 4                                           0.096231
#
#    Depth_CT_Espessura_Crustal_Area_PUC_RJ  falha_dist  1_M_falha_dist  \
# 0                                6.007724    1.942729        3.056931
# 1                               -1.820362    1.246084        2.375346
# 2                               -0.304652    0.587301       -0.014905
# ...

# %%
X=np.array(df.iloc[:,:])

# %%
# load the model from disk
filename='model_mlp_16.sav'
loaded_model = joblib.load(filename)
#result = loaded_model.score(X_test, Y_test)
#print(result)

# %%
loaded_model.predict(X)
# Out:
# array([0, 0, 0, 1, 3, 1, 3, 1, 1, 0, 0, 2, 2, 2, 0, 1, 2, 0, 3, 2, 0, 3,
#        2, 2, 0, 0, 1, 0, 1, 1, 2, 3, 1, 0, 0, 0, 3, 3, 3, 0, 0, 0, 1, 0])

# %% [markdown]
# Co2 <10: 0
# Co2 <30: 1
# Co2 <50: 2
# Co2 >50: 3
